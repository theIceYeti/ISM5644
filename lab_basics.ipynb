# %% [markdown]
# ### TYPE YOUR NAME HERE (Double Click on the Cell): Conor Murray

# %% [markdown]
# # ISM 5644 - Programming for Analytics
#
# ## Lab Exercise: Jupyter Notebook and Basic Operations

# %% [markdown]
# ### Overview:
# This lab covers Jupyter notebook basics, variable assignment, variable type conversion, and numerical operations.

# %% [markdown]
# ### Task:
# The code cells in this notebook have been left blank. You task is to complete these cells and provide the execution results. The corresponding question text for each code cell is provided above the cell. Once you have completed the lab, you should publish your notebook code (the code in the .ipynb file) as a "Secret Gist" on your GitHub repository and obtain the Gist ID.
# ### Submission Format:
# There are two deliverables of this lab: 1) the Gist ID and 2) the completed .ipynb file. Both of these should be submitted on Canvas using the corresponding lab submission link by the due date indicated on Canvas.

# %% [markdown]
# ### Steps:

# %% [markdown]
# #### Jupyter Notebook:
# Each Jupyter notebook is a collection of cells. A cell is a container for text to be displayed in the notebook or code to be executed by the notebook's kernel. Cells form the body of a notebook. There are two types of cells in a notebook. The first one is the “Code” type. A code cell contains code to be executed in the kernel and displays its output below. The second one is the “Markdown” type. A Markdown cell contains text formatted using Markdown and displays its output in-place when it is run. You can edit the contents of a run markdown cell by double clicking on the cell. Try double clicking on this cell now. When you are done, you can "execute" the cell (markdown or code) by clicking on the "Run" button. <b>Alternatively, you can run the cell using the Shift+Enter keyboard shortcut</b>.

# %% [markdown]
# #### 0.1. Type print("Hello World") into the next code cell below and click "Run". The execution of the cell block should generate an output, which is displayed under the expression.

# %%
print("Hello World")
# Enter your answer to the question above in this cell. Do not forget to run the cell before submitting your notebook.
# Out:
# Hello World

# %% [markdown]
# #### 0.2. Change the type of the cell below to “Markdown”. Type “Basic calculations:” in the new cell.

# %% [markdown]
# Basic calculations

# %% [markdown]
# #### 1. Define two variables, one named length making it refer to 3.5 and the other named width making it refer to 1.55. Then, print length and width.

# %%
length = 3.5
width = 1.55
print(length, width)
# Out:
# 3.5 1.55

# %% [markdown]
# #### 2. Increase the value of the length variable by 2 and print the new value.

# %%
length = length +2
print(length)
# Out:
# 5.5

# %% [markdown]
# #### 3. Define a variable called height and assign the integer value 5 to this variable. Next, print the height variable value.

# %%
height = 5
print(height)
# Out:
# 5

# %% [markdown]
# #### 4. Define a new variable called height_extension and assign the value of 3 to this variable. Next, write an *augmented assignment* statement that increments height by the value associated with height_extension. That is, add the value associated with height_extension to that associated with height and assign the result to height. Finally, print the height variable value.

# %%
height_extension = 3
height = height + height_extension
print(height)
# Out:
# 8

# %% [markdown]
# #### 5.1. Convert the height variable to string representation and assign the new value to a variable called height_str.
# #### 5.2. Convert the height variable to floating-point representation and assign the new value to a variable called height_float.
# #### 5.3. Print out height_str and height_float.

# %%
height_str = str(height)
height_float = float(height)
print(height_str, height_float)
# Out:
# 8 8.0

# %% [markdown]
# #### 6.1. Calculate the volume of a box that has the dimensions of length, width, and height variables. Assign this value to a variable named "volume".
# #### 6.2. Print out the following sentence: *The value of volume is: X*. Here, X should display the value of the volume variable (but not the character X). Next, return the type of volume on a new line.

# %%
volume = length * width * height
print("Thew value of volume is: ", volume)
# Out:
# Thew value of volume is:  68.2

# %% [markdown]
# #### 7.1. Ask the user for a number to compare it with volume using an input statement. For example, the command on the screen should say: 'Enter a number to compare with volume:'. Then, assign the entered value to a variable called to_compare.
# Hint: Use the function "input" to obtain the user input. _Notice that the result of input is always a string type_.
# #### 7.2. Print the question: 'Is volume greater than *to_compare*?' on the screen. *to_compare* should display the value of the variable, but not the word '*to compare*'.
# #### 7.3. Compare the value of the volume variable to the value of the to_compare variable and return the result as a boolean (True or False).

# %%
to_compare = int(input("Enter a number to compare with volume:"))
print("Is volume greater than ", to_compare)
print(volume > to_compare)
# Out:
# Enter a number to compare with volume: 5
# Is volume greater than  5
# True

# %% [markdown]
# #### 8. Write a program that prompts the user for a number. Take that number, add 2, multiply by 3, subtract 6, and divide by 3. Print out the result, which should be the number you started with.
# Hint: Be flexible with the input -- integer and float should both be acceptable.

# %%
num = int(input("Enter a numer:"))
num + 2
num * 3
num - 6 
num / 3
print(num)
# Out:
# Enter a numer: 7
# 7

# %% [markdown]
# #### 9. Define a variable called x and set its value to 2, i.e., x = 2. Next, calculate the following mathematical expression in Python: (x<sup>4</sup> + 7 - 3 * 4) / 5 and print out the result.

# %%
x = 2
x = x * x * x * x
x = x + 7 
x = x - 3
x = x * 4
print(x)
# Out:
# 80

# %% [markdown]
# #### 10. A day has 86,400 seconds (24 x 60 x 60). Write a program that first asks the user for an input between 1 and 86,400 and then outputs this value in hours, minutes, and seconds with a 24-hour clock. For example, an input of 70,000 should print out: '19 hours, 26 minutes, 40 seconds'
# Hint: One possibility is to use *integer quotient* character for calculations.

# %%
seconds = int(input("Enter a number between 1 and 86400: "))
hours = seconds // 3600
remainder = seconds % 3600
print(hours)
minutes = remainder // 60
print(minutes)
remainder = remainder % 60
seconds = remainder 
print(seconds)
# Out:
# Enter a number between 1 and 86400:  70000
# 19
# 26
# 40

# %% [markdown]
# #### 11. Write a program that asks the user for the number of males and the number of females registered in a class using two separate inputs ("Enter number of males:", "Enter number of females:"). Then, print out the ratio of males in the entire class and the ratio of females in the entire class in two separate lines.
# Hint: An example outcome is as follows:<br>
# > Enter number of males:13<br>
# > Enter number of females:5<br>
# > Ratio of males: 0.7222222222222222<br>
# > Ratio of females: 0.2777777777777778

# %%
males = int(input("Enter number of males"))
females = int(input("Enter number of females"))
ratio_females = females / males
ratio_males = 1 - ratio_females
print(ratio_males)
print(ratio_females)
# Out:
# Enter number of males 17
# Enter number of females 5
# 0.7058823529411764
# 0.29411764705882354

# %% [markdown]
# #### 12. Solve the following problem: Write a program to calculate the materials needed for an ornamental garden according to the design below. In this design, the blue areas represent flowerbeds and the yellow areas are filled with stone, mulch, or other fill material. The garden is a perfect square. The four outer flowerbeds are congruent semicircles and the central flowerbed is a perfect circle.
# ![lab_1-2_q6_image.PNG](attachment:lab_1-2_q6_image.PNG)
#
# #### The dimensions and other parameters of the garden are as follows:
# ##### The side length of the finished garden (in feet): 10
# ##### The depth of the flowerbeds (in feet): 0.8
# ##### The depth of the filled areas (in feet): 0.6
#
# #### Given these values, calculate and print out the following:
# - Total cubic feet of soil for the garden, rounded to one decimal place
# - Total cubic feet of fill material for the garden, rounded to one decimal place
# - Note: You can use the round() function for rounding.

# %%
flower = 3.141 * 6.25
flower_beds = flower * 3
filled_area = 100 - flower_beds
soil = flower_beds * 0.8
filled = filled_area * 0.6
print("soil needed ", soil, " ft cubed" )
print("fill material needed ", filled, " ft cubed" )
# Out:
# soil needed  47.11500000000001  ft cubed
# fill material needed  24.663749999999997  ft cubed

# %%
radius of the circle is 2.5 ft so the area of all 3 full circles is 3* (pi (2.5)^2 ) and the area of the filled in areas is 100 ft - area of the flower beds
